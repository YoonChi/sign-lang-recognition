# %%
import cv2
import numpy as np
import sys
import time
import os 
import uuid 

a = 1 

background = None
accumulated_weight = 0.5

ROI_top = 100
ROI_bottom = 300
ROI_right = 150
ROI_left = 350

IMAGES_PATH = '/Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/'


def cal_accum_avg(frame, accumulated_weight):

    global background
    
    if background is None:
        background = frame.copy().astype("float")
        return None

    cv2.accumulateWeighted(frame, background, accumulated_weight)

# breakpoint()
# print("went past the breakpoint")

def segment_hand(frame, threshold=25):
    global background
    
    diff = cv2.absdiff(background.astype("uint8"), frame)

    _ , thresholded = cv2.threshold(diff, threshold, 255, cv2.THRESH_BINARY)

    # Grab the external contours for the image
    contours, hierarchy = cv2.findContours(thresholded.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) == 0:
        return None
    else:
        
        hand_segment_max_cont = max(contours, key=cv2.contourArea)
        
        return (thresholded, hand_segment_max_cont)


cam = cv2.VideoCapture(0)


num_frames = 0
element = 10
num_imgs_taken = 0

while True:
    ret, frame = cam.read()

    # filpping the frame to prevent inverted image of captured frame...
    frame = cv2.flip(frame, 1)
        
    frame_copy = frame.copy()

    roi = frame[ROI_top:ROI_bottom, ROI_right:ROI_left]

    gray_frame = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)
    
    gray_frame = cv2.GaussianBlur(gray_frame, (9, 9), 0)
    
    time.sleep(0.2)

    if num_frames < 60:
        cal_accum_avg(gray_frame, accumulated_weight)
        if num_frames <= 59:
                    
            cv2.putText(frame_copy, "FETCHING BACKGROUND...PLEASE WAIT", (80, 400), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,0,255), 2)
            #cv2.imshow("Sign Detection",frame_copy)
         
    #Time to configure the hand specifically into the ROI...
    elif num_frames <= 100: 
            
        hand = segment_hand(gray_frame) # image converted 
        
        cv2.putText(frame_copy, "Adjust hand...Gesture for" + str(element), (200, 400), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
        
        # Checking if hand is actually detected by counting number of contours detected...
        if hand is not None:
            
            thresholded, hand_segment = hand

            # Draw contours around hand segment
            cv2.drawContours(frame_copy, [hand_segment + (ROI_right, ROI_top)], -1, (255, 0, 0),1)
            
            cv2.putText(frame_copy, str(num_frames)+"For" + str(element), (70, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

            # Also display the thresholded image
            cv2.imshow("Thresholded Hand Image", thresholded)
    
    else: 
                
        # Segmenting the hand region...
        hand = segment_hand(gray_frame)
        
        # Checking if we are able to detect the hand...
        if hand is not None:
            
            # unpack the thresholded img and the max_contour...
            thresholded, hand_segment = hand

            # Drawing contours around hand segment
            cv2.drawContours(frame_copy, [hand_segment + (ROI_right, ROI_top)], -1, (255, 0, 0),1)
            
            cv2.putText(frame_copy, str(num_frames), (70, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            #cv2.putText(frame_copy, str(num_frames)+"For" + str(element), (70, 45), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            cv2.putText(frame_copy, str(num_imgs_taken) + 'images' +"For" + str(element), (200, 400), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)
            
            # Displaying the thresholded image
            cv2.imshow("Thresholded Hand Image", thresholded)
            if num_imgs_taken <= 100:
                imgname = os.path.join(IMAGES_PATH, str(a), str(a)+'{}.jpg'.format(str(uuid.uuid1())))
                print(imgname)
                a +=1
                
                cv2.imwrite(imgname, thresholded)
#                 cv2.imwrite(r"/Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/"+str(element)+"/" + str(num_imgs_taken+300) + '.jpg', thresholded)
#                 cv2.imwrite(r"\\gesture\\x"+"\\" + str(num_imgs_taken) + '.jpg', thresholded)

            else:
                break
            num_imgs_taken +=1
        else:
            cv2.putText(frame_copy, 'No hand detected...', (200, 400), cv2.FONT_HERSHEY_SIMPLEX, 1, (0,0,255), 2)

    # Drawing ROI on frame copy
    cv2.rectangle(frame_copy, (ROI_left, ROI_top), (ROI_right, ROI_bottom), (255,128,0), 3)
    
    cv2.putText(frame_copy, "DataFlair hand sign recognition_ _ _", (10, 20), cv2.FONT_ITALIC, 0.5, (51,255,51), 1)
    
    # increment the number of frames for tracking
    num_frames += 1

    # Display the frame with segmented hand
    cv2.imshow("Sign Detection", frame_copy)

    # Closing windows with Esc key...(any other key with ord can be used too.)
    k = cv2.waitKey(1) & 0xFF

    if k == 27:
        break

# Releasing camera & destroying all the windows...

cv2.destroyAllWindows()
cam.release()
# Out:
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/1/14c64aa26-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/2/24c89b302-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/3/34cb0ebd4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/4/44cd4bece-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/5/54cf861f8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/6/64d1bdd40-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/7/74d3f99d8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/8/84d63436a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/9/94d8657c4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/10/104daaa84a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/11/114dce101e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/12/124df15efc-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/13/134e14c5a4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/14/144e385dca-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/15/154e5c44e2-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/16/164e7f172e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/17/174ea32628-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/18/184ec7393c-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/19/194eea3e50-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/20/204f0dc9a6-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/21/214f311d70-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/22/224f5576de-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/23/234f7922c8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/24/244f9cd2f4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/25/254fbfc3f4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/26/264ff7d94c-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/27/27501ca0ba-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/28/285041352e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/29/2950675e3e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/30/30508a9340-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/31/3150aed4bc-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/32/3250d2bf62-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/33/3350f6105c-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/34/3451198190-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/35/35513cf8c8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/36/365160e1c0-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/37/3751838694-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/38/3851a7862a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/39/3951cbc1fc-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/40/4051ef3a92-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/41/4152124e24-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/42/4252366962-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/43/4352599932-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/44/44527dab1a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/45/4552a15f88-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/46/4652c52350-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/47/4752e884e4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/48/48530bd3ae-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/49/49532f1fd0-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/50/50535304b8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/51/515376c182-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/52/52539a15c4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/53/5353be6b54-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/54/5453e0f5a2-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/55/5554051568-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/56/565428a5f0-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/57/57544c87c2-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/58/58546ff46e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/59/5954931a8e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/60/6054b6d1ae-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/61/6154dacaa0-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/62/6254fe4660-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/63/635520eb70-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/64/645545d5ac-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/65/6555694dc0-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/66/66558bcb98-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/67/6755afc944-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/68/6855d3b052-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/69/6955f782d4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/70/70561b6866-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/71/71563e0a1a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/72/725661d56c-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/73/735685ad20-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/74/7456a8da48-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/75/7556cc711a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/76/7656f012b4-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/77/775714161e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/78/785737bdf8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/79/79575af34a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/80/80577edcce-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/81/8157a29f2e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/82/8257c570a8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/83/8357e95a7c-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/84/84580ce3fc-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/85/8558313220-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/86/86585407d2-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/87/875877931e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/88/88589b6884-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/89/8958bf6324-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/90/9058e1fb8c-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/91/915905f474-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/92/925929d2d6-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/93/93594d774a-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/94/9459716b1e-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/95/955993de88-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/96/9659b7e5bc-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/97/9759dc4e20-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/98/9859ff4f10-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/99/995a22cfa8-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/100/1005a474720-b21a-11ec-9663-acde48001122.jpg
# /Users/yooniiechi/Desktop/AI/6720-artificial-intelligence/output-images/101/1015a6a2a9c-b21a-11ec-9663-acde48001122.jpg
